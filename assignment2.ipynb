# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Data Exploration
# ### Explore the data, list down the unique values in each feature and find its length.
# ### Perform the statistical analysis and renaming of the columns.

# %%
ordata=pd.read_csv('Employee.csv')
data=ordata.copy()
data
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
data.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
data.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
data.shape
# Out:
# (148, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
# change name of the column
df=ordata.copy()
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.head()
# Out:
#    company   age  salary     place country  gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %% [markdown]
# ### Explore unique values and their counts

# %%
uni_val_company= df['company'].unique()
print(uni_val_company)
uni_count_company=len(uni_val_company)
uni_count_company
# Out:
# ['TCS' 'Infosys' 'CTS' nan 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']
# 7

# %%
for x in df.columns:
    print(f"Column: {x}")
    print(df[x].unique())
    #print(len(df[col].unique())
    print("-" * 30)
# Out:
# Column: company
# ['TCS' 'Infosys' 'CTS' nan 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']
# ------------------------------
# Column: age
# [20. 30. 35. 40. 23. nan 34. 45. 18. 22. 32. 37. 50. 21. 46. 36. 26. 41.
#  24. 25. 43. 19. 38. 51. 31. 44. 33. 17.  0. 54.]
# ------------------------------
# Column: salary
# [  nan 2300. 3000. 4000. 5000. 6000. 7000. 8000. 9000. 1089. 1234. 3030.
#  3045. 3184. 4824. 5835. 7084. 8943. 8345. 9284. 9876. 2034. 7654. 2934.
#  4034. 5034. 8202. 9024. 4345. 6544. 6543. 3234. 4324. 5435. 5555. 8787.
#  3454. 5654. 5009. 5098. 3033.]
# ------------------------------
# Column: place
# ['Chennai' 'Mumbai' 'Calcutta' 'Delhi' 'Podicherry' 'Cochin' nan 'Noida'
#  'Hyderabad' 'Bhopal' 'Nagpur' 'Pune']
# ------------------------------
# Column: country
# ['India']
# ------------------------------
# Column: gender
# [0 1]
# ------------------------------

# %%
# Explore unique values and their counts
unique_values = {col: df[col].unique() for col in df.columns}

# Display the results
print("Unique Values:")
for col, values in unique_values.items():
    print(f"{col}: {values[:10]}... (and {len(values)} more)")  # Display only first 10 values


# Explore unique values and their counts
unique_counts = {col: len(df[col].unique()) for col in df.columns}

# Display the results
print("\nCounts of Unique Values:")
for col, count in unique_counts.items():
    print(f"{col}: {count}")
# Out:
# Unique Values:
# company: ['TCS' 'Infosys' 'CTS' nan 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']... (and 7 more)
# age: [20. 30. 35. 40. 23. nan 34. 45. 18. 22.]... (and 30 more)
# salary: [  nan 2300. 3000. 4000. 5000. 6000. 7000. 8000. 9000. 1089.]... (and 41 more)
# place: ['Chennai' 'Mumbai' 'Calcutta' 'Delhi' 'Podicherry' 'Cochin' nan 'Noida'
#  'Hyderabad' 'Bhopal']... (and 12 more)
# country: ['India']... (and 1 more)
# gender: [0 1]... (and 2 more)
#
# Counts of Unique Values:
# company: 7
# age: 30
# salary: 41
# place: 12
# country: 1
# gender: 2

# %% [markdown]
# ### Summary statistics for numerical columns

# %%
# numerical statistics

print("Numerical Summary:")

data.describe()
# Out:
# Numerical Summary:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
print("\nCategorical Summary:")

# Summary statistics for categorical columns
df.describe(include=["object"])
# Out:
# Categorical Summary:
#        company   place country
# count      140     134     148
# unique       6      11       1
# top        TCS  Mumbai   India
# freq        53      37     148

# %% [markdown]
# ### Rename columns

# %%
# Rename columns
df.rename(columns={
    "company": "Company_Name",
    "age": "Employee_Age",
    "salary": "Employee_Salary",
    "place": "Work_Location",
    "country": "Employee_Country",
    "gender": "Employee_Gender",
}, inplace=True)


print(df.columns)
df.head()
# Out:
# Index(['Company_Name', 'Employee_Age', 'Employee_Salary', 'Work_Location',
#        'Employee_Country', 'Employee_Gender'],
#       dtype='object')
#   Company_Name  Employee_Age  Employee_Salary Work_Location Employee_Country  \
# 0          TCS          20.0              NaN       Chennai            India
# 1      Infosys          30.0              NaN        Mumbai            India
# 2          TCS          35.0           2300.0      Calcutta            India
# 3      Infosys          40.0           3000.0         Delhi            India
# 4          TCS          23.0           4000.0        Mumbai            India
#
#    Employee_Gender
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# ### Data Cleaning:
# #### Find the missing and inappropriate values, treat them appropriately.
# #### Remove all duplicate rows.
# #### Find the outliers.
# #### Replace the value 0 in age as NaN
# #### Treat the null values in all columns using any measures(removing/ replace the values with mean/median/mode)

# %%
# Check for missing values
missing_summary = df.isnull().sum()
print("Missing values per column:")
print(missing_summary)
# Out:
# Missing values per column:
# Company_Name         8
# Employee_Age        18
# Employee_Salary     24
# Work_Location       14
# Employee_Country     0
# Employee_Gender      0
# dtype: int64

# %%
# Replace 0 in Age with NaN
df['Employee_Age'] = df['Employee_Age'].replace(0, np.nan)
df['Employee_Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 148 entries, 0 to 147
# Series name: Employee_Age
# Non-Null Count  Dtype
# --------------  -----
# 124 non-null    float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %% [markdown]
# #### Remove duplicates

# %%
# Remove duplicates
df1=ordata.copy()
df_shape = df1.shape
df = df.drop_duplicates()
df_treated_shape = df.shape

print(f"Rows before removing duplicates: {df_shape[0]}")
print(f"Rows after removing duplicates: {df_treated_shape[0]}")
# Out:
# Rows before removing duplicates: 148
# Rows after removing duplicates: 144

# %% [markdown]
# #### Find Outliers

# %%
# Detect outliers using IQR method
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"Column: {col} | Number of outliers: {outliers.shape[0]}")
# Out:
# Column: Employee_Age | Number of outliers: 0
# Column: Employee_Salary | Number of outliers: 0
# Column: Employee_Gender | Number of outliers: 32

# %% [markdown]
# #### Replace missing values with mean/median/mode

# %%
# Replace missing values with mean/median/mode
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        # Replace with mean for numerical columns
        df[col] = df[col].fillna(df[col].mean())
    else:
        # Replace with mode for categorical columns
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company_Name      144 non-null    object
#  1   Employee_Age      144 non-null    float64
#  2   Employee_Salary   144 non-null    float64
#  3   Work_Location     144 non-null    object
#  4   Employee_Country  144 non-null    object
#  5   Employee_Gender   144 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.9+ KB

# %% [markdown]
# #### Data Analysis: (Score : 2)
# Filter the data with age >40 and salary<5000
# Plot the chart with age and salary
# Count the number of people from each place and represent it visually

# %%
filtered_data = df[(df['Employee_Age'] > 40) & (df['Employee_Salary'] < 5000)]
filtered_data
# Out:
#     Company_Name  Employee_Age  Employee_Salary Work_Location  \
# 21       Infosys          50.0           3184.0         Delhi
# 32       Infosys          45.0           4034.0      Calcutta
# 39       Infosys          41.0           3000.0        Mumbai
# 50       Infosys          41.0           3000.0       Chennai
# 57       Infosys          51.0           3184.0     Hyderabad
# 68       Infosys          43.0           4034.0        Mumbai
# 75       Infosys          44.0           3000.0        Cochin
# 86       Infosys          41.0           3000.0         Delhi
# 93       Infosys          54.0           3184.0        Mumbai
# 104      Infosys          44.0           4034.0         Delhi
# 122      Infosys          44.0           3234.0        Mumbai
# 129      Infosys          50.0           3184.0      Calcutta
# 138          CTS          44.0           3033.0        Cochin
# 140      Infosys          44.0           4034.0     Hyderabad
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(filtered_data['Employee_Age'], filtered_data['Employee_Salary'], color='blue', alpha=0.7)
plt.title('Scatter Plot of Age vs Salary (Filtered)')
plt.xlabel('Employee_Age')
plt.ylabel('Employee_Salary')
plt.grid(True)
plt.show()

# %%
place_counts = df['Work_Location'].value_counts()

# %%
plt.figure(figsize=(12, 8))
place_counts.plot(kind='bar', color='orange', alpha=0.8)
plt.title('Number of People from Each Place')
plt.xlabel('Work_Location')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### Data Encoding: (Score : 2)
# Convert categorical variables into numerical representations using techniques such as one-hot encoding, label encoding, making them suitable for analysis by machine learning algorithms.

# %%
df1.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
# Step 1: Label Encoding for 'Company'
label_encoder = LabelEncoder()
df['Company_Encoded'] = label_encoder.fit_transform(df['Company'])

# Step 2: One-Hot Encoding for 'Place'
df = pd.get_dummies(df, columns=['Place'], prefix='Place')
df
# Out:
#         Company_Name  Employee_Age  Employee_Salary Employee_Country  \
# 0                TCS          20.0      5283.471074            India
# 1            Infosys          30.0      5283.471074            India
# 2                TCS          35.0      2300.000000            India
# 3            Infosys          40.0      3000.000000            India
# 4                TCS          23.0      4000.000000            India
# ..               ...           ...              ...              ...
# 142  Infosys Pvt Lmt          22.0      8202.000000            India
# 143              TCS          33.0      9024.000000            India
# 145          Infosys          44.0      4034.000000            India
# 146              TCS          33.0      5034.000000            India
# 147          Infosys          22.0      8202.000000            India
#
#      Employee_Gender  Company_Encoded  Place_Bhopal  Place_Calcutta  \
# 0                  0                4         False           False
# ...

# %% [markdown]
# #### Feature Scaling
# After the process of encoding, perform the scaling of the features using standardscaler and minmaxscaler.

# %%
# Import libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd

# Extract numerical columns
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns

# %%
# StandardScaler
scaler_standard = StandardScaler()
df_scaled_standard = scaler_standard.fit_transform(df[numerical_features])
df_scaled_standard = pd.DataFrame(df_scaled_standard, columns=numerical_features)

# %%
# MinMaxScaler
scaler_minmax = MinMaxScaler()
df_scaled_minmax = scaler_minmax.fit_transform(df[numerical_features])
df_scaled_minmax = pd.DataFrame(df_scaled_minmax, columns=numerical_features)

# %%
# Example: Replace numerical features in the original DataFrame
df[numerical_features] = df_scaled_standard  # Or use df_scaled_minmax

# %%
df
# Out:
#         Company_Name  Employee_Age  Employee_Salary Employee_Country  \
# 0                TCS     -1.467376         0.000000            India
# 1            Infosys     -0.248759         0.000000            India
# 2                TCS      0.360549        -1.264122            India
# 3            Infosys      0.969858        -0.967526            India
# 4                TCS     -1.101791        -0.543818            India
# ..               ...           ...              ...              ...
# 142  Infosys Pvt Lmt      0.116826        -0.105703            India
# 143              TCS     -1.223652         1.236606            India
# 145          Infosys           NaN              NaN            India
# 146              TCS           NaN              NaN            India
# 147          Infosys           NaN              NaN            India
#
#      Employee_Gender  Company_Encoded  Place_Bhopal  Place_Calcutta  \
# 0          -0.534522                4         False           False
# ...
